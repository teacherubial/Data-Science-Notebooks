# %% [markdown]
# # Setting Up the Environment
# In this first notebook, you're going to get introduced to Jupyter. In short, it's a way that we can create Interactive Python NoteBooks (that's why the files have `.ipynb` as their extension).
#
# This document that you're in is called a **notebook**.
#
# The first activity that we're going to do is to get used to Markdown. It's a scripting language that is used to make rich text content.
#
# ## 1. Introduction to Markdown
# Markdown is a scripting language that allows us to make rich-text (text with _different_ **emphasis**) using symbols. It helps cut down a lot of mouse clicks and makes formatting relatively easy.
#
# Do the markdown tutorial at [Markdown Tutorial](https://www.markdowntutorial.com/).
#
# Once you're done, markdown the following cell.

# %% [markdown]
# ## Make this a heading level two.
#
# *Make this italicized.*
#
# **Make this bold.**
#
# Create a table with 3 columns and one header row.
#
# Name            | Alter Ego     | Super Powers
# ---             | ---           | ---
# Bruce Wayne     | Batman        | None
# Natasha Romanov | Black Widow   | None
# Bruce Banner    | Hulk          | He gets bigger?

# %% [markdown]
# ### Exercise 1
# Insert an [image](https://images.google.com) here.
#
# ![Grumpy Cat](https://pyxis.nymag.com/v1/imgs/1a6/fd2/90b8f4c3502e59a232ef01300bc6287c0d-29-grumpy-cat.rsquare-zoom.w190.jpg)
#
# `print("hello world!")`

# %%
import math

def area_of_circle(radius):
    return math.pi * radius ** 2

radius = input("Enter the radius of a circle:")

print(area_of_circle(float(radius)))
# Out:
# Enter the radius of a circle: 10
# 314.1592653589793

# %%
area_of_circle(5.5)
# Out:
# 95.03317777109125
